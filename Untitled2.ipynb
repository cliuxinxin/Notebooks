# %%
import mindmeld as mm
mm.configure_logs()
bp_name = 'food_ordering'
mm.blueprint(bp_name)
# Out:
# Using cached 'food_ordering' app archive
# Created 'food_ordering' app at '/Users/liuxinxin/Documents/GitHub/notebooks/food_ordering'
# Using cached 'food_ordering' kb archive
# GET http://localhost:9200/_cluster/health [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/elasticsearch5/connection/http_urllib3.py", line 135, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=Retry(False), headers=request_headers, **kw)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py", line 343, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py", line 686, in reraise
#     raise value
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 180, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x12bdf5da0>: Failed to establish a new connection: [Errno 61] Connection refused
# GET http://localhost:9200/_cluster/health [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/elasticsearch5/connection/http_urllib3.py", line 135, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=Retry(False), headers=request_headers, **kw)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py", line 343, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py", line 686, in reraise
#     raise value
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 180, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x12bdf5f60>: Failed to establish a new connection: [Errno 61] Connection refused
# GET http://localhost:9200/_cluster/health [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/elasticsearch5/connection/http_urllib3.py", line 135, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=Retry(False), headers=request_headers, **kw)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py", line 343, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py", line 686, in reraise
#     raise value
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 180, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x12bdf5390>: Failed to establish a new connection: [Errno 61] Connection refused
# GET http://localhost:9200/_cluster/health [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/elasticsearch5/connection/http_urllib3.py", line 135, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=Retry(False), headers=request_headers, **kw)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py", line 343, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py", line 686, in reraise
#     raise value
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/Users/liuxinxin/anaconda3/lib/python3.6/site-packages/urllib3/connection.py", line 180, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x12bdf5e10>: Failed to establish a new connection: [Errno 61] Connection refused
# Cannot set up knowledge base. Unable to connect to Elasticsearch instance at 'localhost'. Confirm it is running or specify an alternate instance with the MM_ES_HOST environment variable
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/elasticsearch5/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     134
# --> 135             response = self.pool.urlopen(method, url, body, retries=Retry(False), headers=request_headers, **kw)
#     136             duration = time.time() - start
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     342             # Disabled, indicate to re-raise the error.
# --> 343             raise six.reraise(type(error), error, _stacktrace)
#     344
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     685             raise value.with_traceback(tb)
# --> 686         raise value
#     687
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~/anaconda3/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~/anaconda3/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~/anaconda3/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~/anaconda3/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/anaconda3/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     195     def connect(self):
# --> 196         conn = self._new_conn()
#     197         self._prepare_conn(conn)
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     179             raise NewConnectionError(
# --> 180                 self, "Failed to establish a new connection: %s" % e)
#     181
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x12bdf5e10>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/mindmeld/components/_elasticsearch_helpers.py in does_index_exist(app_namespace, index_name, es_host, es_client, connect_timeout)
#      66         # Confirm ES connection with a shorter timeout
# ---> 67         es_client.cluster.health(request_timeout=connect_timeout)
#      68         return es_client.indices.exists(index=scoped_index_name)
#
# ~/anaconda3/lib/python3.6/site-packages/elasticsearch5/client/utils.py in _wrapped(*args, **kwargs)
#      72                     params[p] = kwargs.pop(p)
# ---> 73             return func(*args, params=params, **kwargs)
#      74         return _wrapped
#
# ~/anaconda3/lib/python3.6/site-packages/elasticsearch5/client/cluster.py in health(self, index, params)
#      32         return self.transport.perform_request('GET', _make_path('_cluster',
# ---> 33             'health', index), params=params)
#      34
#
# ~/anaconda3/lib/python3.6/site-packages/elasticsearch5/transport.py in perform_request(self, method, url, params, body)
#     311             try:
# --> 312                 status, headers, data = connection.perform_request(method, url, params, body, ignore=ignore, timeout=timeout)
#     313
#
# ~/anaconda3/lib/python3.6/site-packages/elasticsearch5/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     143                 raise ConnectionTimeout('TIMEOUT', str(e), e)
# --> 144             raise ConnectionError('N/A', str(e), e)
#     145
#
# ConnectionError: ConnectionError(<urllib3.connection.HTTPConnection object at 0x12bdf5e10>: Failed to establish a new connection: [Errno 61] Connection refused) caused by: NewConnectionError(<urllib3.connection.HTTPConnection object at 0x12bdf5e10>: Failed to establish a new connection: [Errno 61] Connection refused)
#
# During handling of the above exception, another exception occurred:
#
# KnowledgeBaseConnectionError              Traceback (most recent call last)
# <ipython-input-2-a12b8a728e44> in <module>()
#       2 mm.configure_logs()
#       3 bp_name = 'food_ordering'
# ----> 4 mm.blueprint(bp_name)
#
# ~/anaconda3/lib/python3.6/site-packages/mindmeld/_util.py in __call__(self, name, app_path, es_host, skip_kb)
#      97         app_path = self.setup_app(name, app_path)
#      98         if bp_config.get('kb', True) and not skip_kb:
# ---> 99             self.setup_kb(name, app_path, es_host=es_host)
#     100         return app_path
#     101
#
# ~/anaconda3/lib/python3.6/site-packages/mindmeld/_util.py in setup_kb(cls, name, app_path, es_host)
#     177                              'instance with the MM_ES_HOST environment variable', es_host)
#     178
# --> 179                 raise ex
#     180
#     181         logger.info('Created %r knowledge base at %r', name, es_host)
#
# ~/anaconda3/lib/python3.6/site-packages/mindmeld/_util.py in setup_kb(cls, name, app_path, es_host)
#     171
#     172             try:
# --> 173                 QuestionAnswerer.load_kb(app_namespace, index_name, data_file, es_host)
#     174             except KnowledgeBaseConnectionError as ex:
#     175                 logger.error('Cannot set up knowledge base. Unable to connect to Elasticsearch '
#
# ~/anaconda3/lib/python3.6/site-packages/mindmeld/components/question_answerer.py in load_kb(cls, app_namespace, index_name, data_file, es_host, es_client, connect_timeout)
#     254         docs_count = _doc_count(data_file)
#     255         load_index(app_namespace, index_name, docs, docs_count, DEFAULT_ES_QA_MAPPING,
# --> 256                    DOC_TYPE, es_host, es_client, connect_timeout=connect_timeout)
#     257
#     258
#
# ~/anaconda3/lib/python3.6/site-packages/mindmeld/components/_elasticsearch_helpers.py in load_index(app_namespace, index_name, docs, docs_count, mapping, doc_type, es_host, es_client, connect_timeout)
#     195     try:
#     196         # create index if specified index does not exist
# --> 197         if does_index_exist(app_namespace, index_name, es_host, es_client, connect_timeout):
#     198             logger.warning('Elasticsearch index \'%s\' for application \'%s\' already exists!',
#     199                            index_name, app_namespace)
#
# ~/anaconda3/lib/python3.6/site-packages/mindmeld/components/_elasticsearch_helpers.py in does_index_exist(app_namespace, index_name, es_host, es_client, connect_timeout)
#      69     except EsConnectionError as e:
#      70         logger.debug('Unable to connect to Elasticsearch: %s details: %s', e.error, e.info)
# ---> 71         raise KnowledgeBaseConnectionError(es_host=es_client.transport.hosts)
#      72     except TransportError as e:
#      73         logger.error('Unexpected error occurred when sending requests to Elasticsearch: %s '
#
# KnowledgeBaseConnectionError: Unable to connect to knowledge base. Please verify your connection to: localhost.

# %%
from mindmeld.components import NaturalLanguageProcessor
nlp = NaturalLanguageProcessor(bp_name)
nlp.build()

# %%
from mindmeld.components.dialogue import Conversation
conv = Conversation(nlp=nlp, app_path=bp_name)
conv.say('Hello!')

# %%
conv.say("Get me a pepperoni pizza from firetrail pizza")
